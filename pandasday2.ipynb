# %%
import pandas as pd
df=pd.read_csv('pandayday1\emp1.csv')

# %%
df
# Out:
#     eno   ename    salary  deptno         doj
# 0    10   Amber   1000.00      10  2018-05-14
# 1     2    Amar   1000.00      10  2017-03-22
# 2     8   Sagar   1000.00      20  2020-11-30
# 3     4  Thomas   1000.00      10  2019-08-18
# 4     5    Jade   2000.00      10  2021-02-10
# 5     6   Smith   1000.00      10  2016-12-01
# 6     7  Robert   3000.00      20  2023-06-25
# 7     3    Nick   1000.00      30  2015-09-15
# 8     9   Naman   4000.00      30  2020-01-20
# 9     1   Vikas   1000.00      30  2017-10-03
# 10   11  Dennis  41000.00      20  2024-01-05
# 11   12   Karan   2200.00      20  2018-06-16
# 12   13  Simran   1500.89      10  2019-12-19
# 13   14    Amit   2000.00      30  2022-04-09
# 14   15    Neha   1700.90      20  2021-07-22

# %%
df_eno_ename=pd.read_csv('pandayday1\emp1.csv',usecols=['eno','ename'])

# %%
df1=pd.read_csv('pandayday1\emp1.csv',usecols=['eno'])

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_eno_ename)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=pd.read_csv('pandayday1\emp1.csv',usecols=['eno'])

# %%
df1
# Out:
#     eno
# 0    10
# 1     2
# 2     8
# 3     4
# 4     5
# 5     6
# 6     7
# 7     3
# 8     9
# 9     1
# 10   11
# 11   12
# 12   13
# 13   14
# 14   15

# %%
df1=pd.read_csv('pandayday1\emp1.csv')

# %%
df1['eno']
# Out:
# 0     10
# 1      2
# 2      8
# 3      4
# 4      5
# 5      6
# 6      7
# 7      3
# 8      9
# 9      1
# 10    11
# 11    12
# 12    13
# 13    14
# 14    15
# Name: eno, dtype: int64

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df_eno_ename[['eno','ename']]
# Out:
#     eno   ename
# 0    10   Amber
# 1     2    Amar
# 2     8   Sagar
# 3     4  Thomas
# 4     5    Jade
# 5     6   Smith
# 6     7  Robert
# 7     3    Nick
# 8     9   Naman
# 9     1   Vikas
# 10   11  Dennis
# 11   12   Karan
# 12   13  Simran
# 13   14    Amit
# 14   15    Neha

# %%
type(df_eno_ename)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# eno         int64
# ename      object
# salary    float64
# deptno      int64
# doj        object
# dtype: object

# %%
df
# Out:
#     eno   ename    salary  deptno         doj
# 0    10   Amber   1000.00      10  2018-05-14
# 1     2    Amar   1000.00      10  2017-03-22
# 2     8   Sagar   1000.00      20  2020-11-30
# 3     4  Thomas   1000.00      10  2019-08-18
# 4     5    Jade   2000.00      10  2021-02-10
# 5     6   Smith   1000.00      10  2016-12-01
# 6     7  Robert   3000.00      20  2023-06-25
# 7     3    Nick   1000.00      30  2015-09-15
# 8     9   Naman   4000.00      30  2020-01-20
# 9     1   Vikas   1000.00      30  2017-10-03
# 10   11  Dennis  41000.00      20  2024-01-05
# 11   12   Karan   2200.00      20  2018-06-16
# 12   13  Simran   1500.89      10  2019-12-19
# 13   14    Amit   2000.00      30  2022-04-09
# 14   15    Neha   1700.90      20  2021-07-22

# %%
df.dtypes
# Out:
# eno         int64
# ename      object
# salary    float64
# deptno      int64
# doj        object
# dtype: object

# %%
df
# Out:
#     eno   ename    salary  deptno         doj
# 0    10   Amber   1000.00      10  2018-05-14
# 1     2    Amar   1000.00      10  2017-03-22
# 2     8   Sagar   1000.00      20  2020-11-30
# 3     4  Thomas   1000.00      10  2019-08-18
# 4     5    Jade   2000.00      10  2021-02-10
# 5     6   Smith   1000.00      10  2016-12-01
# 6     7  Robert   3000.00      20  2023-06-25
# 7     3    Nick   1000.00      30  2015-09-15
# 8     9   Naman   4000.00      30  2020-01-20
# 9     1   Vikas   1000.00      30  2017-10-03
# 10   11  Dennis  41000.00      20  2024-01-05
# 11   12   Karan   2200.00      20  2018-06-16
# 12   13  Simran   1500.89      10  2019-12-19
# 13   14    Amit   2000.00      30  2022-04-09
# 14   15    Neha   1700.90      20  2021-07-22

# %%
df=pd.read_csv('pandayday1\emp1.csv',parse_dates=['doj'])

# %%
df
# Out:
#     eno   ename    salary  deptno        doj
# 0    10   Amber   1000.00      10 2018-05-14
# 1     2    Amar   1000.00      10 2017-03-22
# 2     8   Sagar   1000.00      20 2020-11-30
# 3     4  Thomas   1000.00      10 2019-08-18
# 4     5    Jade   2000.00      10 2021-02-10
# 5     6   Smith   1000.00      10 2016-12-01
# 6     7  Robert   3000.00      20 2023-06-25
# 7     3    Nick   1000.00      30 2015-09-15
# 8     9   Naman   4000.00      30 2020-01-20
# 9     1   Vikas   1000.00      30 2017-10-03
# 10   11  Dennis  41000.00      20 2024-01-05
# 11   12   Karan   2200.00      20 2018-06-16
# 12   13  Simran   1500.89      10 2019-12-19
# 13   14    Amit   2000.00      30 2022-04-09
# 14   15    Neha   1700.90      20 2021-07-22

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# eno                int64
# ename             object
# salary           float64
# deptno             int64
# doj       datetime64[ns]
# dtype: object

# %%
df['doj']
# Out:
# 0    2018-05-14
# 1    2017-03-22
# 2    2020-11-30
# 3    2019-08-18
# 4    2021-02-10
# 5    2016-12-01
# 6    2023-06-25
# 7    2015-09-15
# 8    2020-01-20
# 9    2017-10-03
# 10   2024-01-05
# 11   2018-06-16
# 12   2019-12-19
# 13   2022-04-09
# 14   2021-07-22
# Name: doj, dtype: datetime64[ns]

# %%
df['doj'].dt.year
# Out:
# 0     2018
# 1     2017
# 2     2020
# 3     2019
# 4     2021
# 5     2016
# 6     2023
# 7     2015
# 8     2020
# 9     2017
# 10    2024
# 11    2018
# 12    2019
# 13    2022
# 14    2021
# Name: doj, dtype: int64

# %%
df['doj'].dt.day
# Out:
# 0     14
# 1     22
# 2     30
# 3     18
# 4     10
# 5      1
# 6     25
# 7     15
# 8     20
# 9      3
# 10     5
# 11    16
# 12    19
# 13     9
# 14    22
# Name: doj, dtype: int64

# %%
df['doj'].dt.month
# Out:
# 0      5
# 1      3
# 2     11
# 3      8
# 4      2
# 5     12
# 6      6
# 7      9
# 8      1
# 9     10
# 10     1
# 11     6
# 12    12
# 13     4
# 14     7
# Name: doj, dtype: int64

# %%
df=pd.read_csv('pandayday1\emp1.csv',parse_dates=['doj'],dtype={'eno':float})

# %%
df
# Out:
#      eno   ename    salary  deptno        doj
# 0   10.0   Amber   1000.00      10 2018-05-14
# 1    2.0    Amar   1000.00      10 2017-03-22
# 2    8.0   Sagar   1000.00      20 2020-11-30
# 3    4.0  Thomas   1000.00      10 2019-08-18
# 4    5.0    Jade   2000.00      10 2021-02-10
# 5    6.0   Smith   1000.00      10 2016-12-01
# 6    7.0  Robert   3000.00      20 2023-06-25
# 7    3.0    Nick   1000.00      30 2015-09-15
# 8    9.0   Naman   4000.00      30 2020-01-20
# 9    1.0   Vikas   1000.00      30 2017-10-03
# 10  11.0  Dennis  41000.00      20 2024-01-05
# 11  12.0   Karan   2200.00      20 2018-06-16
# 12  13.0  Simran   1500.89      10 2019-12-19
# 13  14.0    Amit   2000.00      30 2022-04-09
# 14  15.0    Neha   1700.90      20 2021-07-22

# %%
df.dtypes
# Out:
# eno              float64
# ename             object
# salary           float64
# deptno             int64
# doj       datetime64[ns]
# dtype: object

# %%
type(df['doj'])
# Out:
# pandas.core.series.Series

# %%
df['doj'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# eno              float64
# ename             object
# salary           float64
# deptno             int64
# doj       datetime64[ns]
# dtype: object

# %%
df.iloc[1]
# Out:
# eno                       2.0
# ename                    Amar
# salary                 1000.0
# deptno                     10
# doj       2017-03-22 00:00:00
# Name: 1, dtype: object

# %%
df.iloc[3]
# Out:
# eno                       4.0
# ename                  Thomas
# salary                 1000.0
# deptno                     10
# doj       2019-08-18 00:00:00
# Name: 3, dtype: object

# %%
df.iloc[1:3]
# Out:
#    eno  ename  salary  deptno        doj
# 1  2.0   Amar  1000.0      10 2017-03-22
# 2  8.0  Sagar  1000.0      20 2020-11-30

# %%
df.iloc[1:]
# Out:
#      eno   ename    salary  deptno        doj
# 1    2.0    Amar   1000.00      10 2017-03-22
# 2    8.0   Sagar   1000.00      20 2020-11-30
# 3    4.0  Thomas   1000.00      10 2019-08-18
# 4    5.0    Jade   2000.00      10 2021-02-10
# 5    6.0   Smith   1000.00      10 2016-12-01
# 6    7.0  Robert   3000.00      20 2023-06-25
# 7    3.0    Nick   1000.00      30 2015-09-15
# 8    9.0   Naman   4000.00      30 2020-01-20
# 9    1.0   Vikas   1000.00      30 2017-10-03
# 10  11.0  Dennis  41000.00      20 2024-01-05
# 11  12.0   Karan   2200.00      20 2018-06-16
# 12  13.0  Simran   1500.89      10 2019-12-19
# 13  14.0    Amit   2000.00      30 2022-04-09
# 14  15.0    Neha   1700.90      20 2021-07-22

# %%
df.iloc[0:]
# Out:
#      eno   ename    salary  deptno        doj
# 0   10.0   Amber   1000.00      10 2018-05-14
# 1    2.0    Amar   1000.00      10 2017-03-22
# 2    8.0   Sagar   1000.00      20 2020-11-30
# 3    4.0  Thomas   1000.00      10 2019-08-18
# 4    5.0    Jade   2000.00      10 2021-02-10
# 5    6.0   Smith   1000.00      10 2016-12-01
# 6    7.0  Robert   3000.00      20 2023-06-25
# 7    3.0    Nick   1000.00      30 2015-09-15
# 8    9.0   Naman   4000.00      30 2020-01-20
# 9    1.0   Vikas   1000.00      30 2017-10-03
# 10  11.0  Dennis  41000.00      20 2024-01-05
# 11  12.0   Karan   2200.00      20 2018-06-16
# 12  13.0  Simran   1500.89      10 2019-12-19
# 13  14.0    Amit   2000.00      30 2022-04-09
# 14  15.0    Neha   1700.90      20 2021-07-22

# %%
df.iloc[5:9]
# Out:
#    eno   ename  salary  deptno        doj
# 5  6.0   Smith  1000.0      10 2016-12-01
# 6  7.0  Robert  3000.0      20 2023-06-25
# 7  3.0    Nick  1000.0      30 2015-09-15
# 8  9.0   Naman  4000.0      30 2020-01-20

# %%
df.iloc[1:9:2]
# Out:
#    eno   ename  salary  deptno        doj
# 1  2.0    Amar  1000.0      10 2017-03-22
# 3  4.0  Thomas  1000.0      10 2019-08-18
# 5  6.0   Smith  1000.0      10 2016-12-01
# 7  3.0    Nick  1000.0      30 2015-09-15

# %%
df=pd.read_csv('pandayday1\emp1.csv',skiprows=range(1,6),nrows=5)

# %%
df
# Out:
#    eno   ename  salary  deptno         doj
# 0    6   Smith    1000      10  2016-12-01
# 1    7  Robert    3000      20  2023-06-25
# 2    3    Nick    1000      30  2015-09-15
# 3    9   Naman    4000      30  2020-01-20
# 4    1   Vikas    1000      30  2017-10-03

# %%
df=pd.read_csv('pandayday1\emp1.csv',delimiter=',')

# %%
df
# Out:
#     eno   ename    salary  deptno         doj
# 0    10   Amber   1000.00      10  2018-05-14
# 1     2    Amar   1000.00      10  2017-03-22
# 2     8   Sagar   1000.00      20  2020-11-30
# 3     4  Thomas   1000.00      10  2019-08-18
# 4     5    Jade   2000.00      10  2021-02-10
# 5     6   Smith   1000.00      10  2016-12-01
# 6     7  Robert   3000.00      20  2023-06-25
# 7     3    Nick   1000.00      30  2015-09-15
# 8     9   Naman   4000.00      30  2020-01-20
# 9     1   Vikas   1000.00      30  2017-10-03
# 10   11  Dennis  41000.00      20  2024-01-05
# 11   12   Karan   2200.00      20  2018-06-16
# 12   13  Simran   1500.89      10  2019-12-19
# 13   14    Amit   2000.00      30  2022-04-09
# 14   15    Neha   1700.90      20  2021-07-22

# %%
df=pd.read_csv('pandayday1\emp2.csv',delimiter=';')

# %%
df
# Out:
#                            eno  ename  salary  deptno         doj
# 0                           10  Amber  1000.0    10.0  2018-05-14
# 1                            2   Amar  1000.0    10.0  2017-03-22
# 2                            8  Sagar  1000.0    20.0  2020-11-30
# 3  4,Thomas,1000,10,2019-08-18    NaN     NaN     NaN         NaN

# %%
df=pd.read_csv('pandayday1\emp2.csv.gz',compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df=pd.read_csv('pandayday1\emp2.csv.gz',compression='gzip')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
for cnk in pd.read_csv('emp.csv',chunksize=5):
    print(cnk)
# Out:
#    eno   ename   salary  deptno         doj
# 0   10   Amber  1000.56      10  2018-05-14
# 1    2    Amar  1000.00      10  2017-03-22
# 2    8   Sagar  1000.00      20  2020-11-30
# 3    4  Thomas  1000.00      10  2019-08-18
# 4    5    Jade  2000.00      10  2021-02-10
#    eno   ename   salary  deptno         doj
# 5    6   Smith  1000.00      10  2016-12-01
# 6    7  Robert  3000.00      20  2023-06-25
# 7    3    Nick  1000.89      30  2015-09-15
# 8    9   Naman  4000.00      30  2020-01-20
# 9    1   Vikas  1000.00      30  2017-10-03
#     eno   ename  salary  deptno         doj
# 10   11  Dennis   41000      20  2024-01-05
# 11   12   Karan    2200      20  2018-06-16
# 12   13  Simran    1500      10  2019-12-19
# 13   14    Amit    2000      30  2022-04-09
# 14   15    Neha    1700      20  2021-07-22

# %%
for cnk in pd.read_csv('emp.csv'):
    print(cnk)
# Out:
# eno
# ename
# salary
# deptno
# doj

# %%
df=pd.read_csv('emp.csv',low_memory='True')
df
# Out:
#     eno   ename    salary  deptno         doj
# 0    10   Amber   1000.56      10  2018-05-14
# 1     2    Amar   1000.00      10  2017-03-22
# 2     8   Sagar   1000.00      20  2020-11-30
# 3     4  Thomas   1000.00      10  2019-08-18
# 4     5    Jade   2000.00      10  2021-02-10
# 5     6   Smith   1000.00      10  2016-12-01
# 6     7  Robert   3000.00      20  2023-06-25
# 7     3    Nick   1000.89      30  2015-09-15
# 8     9   Naman   4000.00      30  2020-01-20
# 9     1   Vikas   1000.00      30  2017-10-03
# 10   11  Dennis  41000.00      20  2024-01-05
# 11   12   Karan   2200.00      20  2018-06-16
# 12   13  Simran   1500.00      10  2019-12-19
# 13   14    Amit   2000.00      30  2022-04-09
# 14   15    Neha   1700.00      20  2021-07-22

# %%
df=pd.read_csv('emp.csv',low_memory='False')
df
# Out:
#     eno   ename    salary  deptno         doj
# 0    10   Amber   1000.56      10  2018-05-14
# 1     2    Amar   1000.00      10  2017-03-22
# 2     8   Sagar   1000.00      20  2020-11-30
# 3     4  Thomas   1000.00      10  2019-08-18
# 4     5    Jade   2000.00      10  2021-02-10
# 5     6   Smith   1000.00      10  2016-12-01
# 6     7  Robert   3000.00      20  2023-06-25
# 7     3    Nick   1000.89      30  2015-09-15
# 8     9   Naman   4000.00      30  2020-01-20
# 9     1   Vikas   1000.00      30  2017-10-03
# 10   11  Dennis  41000.00      20  2024-01-05
# 11   12   Karan   2200.00      20  2018-06-16
# 12   13  Simran   1500.00      10  2019-12-19
# 13   14    Amit   2000.00      30  2022-04-09
# 14   15    Neha   1700.00      20  2021-07-22
